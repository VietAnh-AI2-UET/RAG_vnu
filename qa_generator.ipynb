# %%
import re
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#tao cau hoi va tra loi tu file lich_su_hinh_thanh_vnu
from transformers import AutoModelWithLMHead, AutoTokenizer
import random

# Tải mô hình và tokenizer từ Hugging Face
model_name = "mrm8488/t5-base-finetuned-question-generation-ap"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)

# Hàm đọc file .txt
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Hàm tạo câu hỏi
def generate_question(answer, context, max_length=64):
    input_text = f"answer: {answer} context: {context} </s>"
    features = tokenizer([input_text], return_tensors='pt')
    output = model.generate(
        input_ids=features['input_ids'],
        attention_mask=features['attention_mask'],
        max_length=max_length
    )
    question = tokenizer.decode(output[0], skip_special_tokens=True)
    return question.replace("question: ", "").strip()

# Hàm tạo nhiều câu hỏi và đáp án
def generate_multiple_questions(file_path, num_questions=10):
    text = read_text_file(file_path)
    sentences = sent_tokenize(text)  # Tách văn bản thành các câu
    questions = []
    answers = []

    # Lặp để tạo câu hỏi
    for _ in range(num_questions):
        if not sentences:
            break
        # Chọn ngẫu nhiên một câu làm ngữ cảnh
        context = random.choice(sentences)
        # Chọn một cụm từ hoặc danh từ làm đáp án
        words = context.split()
        answer = random.choice([word for word in words if len(word) > 3])  # Lọc từ ngắn
        try:
            question = generate_question(answer, context)
            questions.append(question)
            answers.append(answer)
        except:
            continue

    return questions, answers

# Hàm lưu câu hỏi và đáp án vào file riêng
def save_to_files(questions, answers, questions_file="questions.txt", answers_file="answers.txt"):
    # Lưu câu hỏi
    with open(questions_file, "w", encoding="utf-8") as q_file:
        for question in questions:
            q_file.write(f"{question}\n")

    # Lưu đáp án
    with open(answers_file, "w", encoding="utf-8") as a_file:
        for answer in answers:
            a_file.write(f"{answer}\n")

# Chạy chương trình
file_path = "data/cleaned_data/en_translated_data/lich_su_hinh_thanh_vnu_cleaned_en.txt"  # Đường dẫn đến file .txt
questions, answers = generate_multiple_questions(file_path, num_questions=40)

# Lưu vào file
save_to_files(questions, answers, questions_file="data/questions_answers/questions/lich_su_hinh_thanh_vnu_questions_en.txt", answers_file="data/questions_answers/answers/lich_su_hinh_thanh_vnu_answers_en.txt")

print(f"Đã tạo {len(questions)} câu hỏi.")
print(f"Câu hỏi được lưu trong: lich_su_hinh_thanh_vnu_questions_en.txt")
print(f"Đáp án được lưu trong: lich_su_hinh_thanh_vnu_answers_en.txt")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# ...

# %%
#tao cau hoi va tra loi thong tin tuyen sinh ulis
from transformers import AutoModelWithLMHead, AutoTokenizer
import random

# Tải mô hình và tokenizer từ Hugging Face
model_name = "mrm8488/t5-base-finetuned-question-generation-ap"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)

# Hàm đọc file .txt
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Hàm tạo câu hỏi
def generate_question(answer, context, max_length=64):
    input_text = f"answer: {answer} context: {context} </s>"
    features = tokenizer([input_text], return_tensors='pt')
    output = model.generate(
        input_ids=features['input_ids'],
        attention_mask=features['attention_mask'],
        max_length=max_length
    )
    question = tokenizer.decode(output[0], skip_special_tokens=True)
    return question.replace("question: ", "").strip()

# Hàm tạo nhiều câu hỏi và đáp án
def generate_multiple_questions(file_path, num_questions=10):
    text = read_text_file(file_path)
    sentences = sent_tokenize(text)  # Tách văn bản thành các câu
    questions = []
    answers = []

    # Lặp để tạo câu hỏi
    for _ in range(num_questions):
        if not sentences:
            break
        # Chọn ngẫu nhiên một câu làm ngữ cảnh
        context = random.choice(sentences)
        # Chọn một cụm từ hoặc danh từ làm đáp án
        words = context.split()
        answer = random.choice([word for word in words if len(word) > 3])  # Lọc từ ngắn
        try:
            question = generate_question(answer, context)
            questions.append(question)
            answers.append(answer)
        except:
            continue

    return questions, answers

# Hàm lưu câu hỏi và đáp án vào file riêng
def save_to_files(questions, answers, questions_file="questions.txt", answers_file="answers.txt"):
    # Lưu câu hỏi
    with open(questions_file, "w", encoding="utf-8") as q_file:
        for question in questions:
            q_file.write(f"{question}\n")

    # Lưu đáp án
    with open(answers_file, "w", encoding="utf-8") as a_file:
        for answer in answers:
            a_file.write(f"{answer}\n")

# Chạy chương trình
file_path = "data/cleaned_data/en_translated_data/thong_tin_tuyen_sinh_ulis_cleaned_en.txt"  # Đường dẫn đến file .txt
questions, answers = generate_multiple_questions(file_path, num_questions=40)

# Lưu vào file
save_to_files(questions, answers, questions_file="data/questions_answers/questions/thong_tin_tuyen_sinh_ulis_questions_en.txt", answers_file="data/questions_answers/answers/thong_tin_tuyen_sinh_ulis_answers_en.txt")

print(f"Đã tạo {len(questions)} câu hỏi.")
print(f"Câu hỏi được lưu trong: thong_tin_tuyen_sinh_ulis_questions_en.txt")
print(f"Đáp án được lưu trong: thong_tin_tuyen_sinh_ulis_answers_en.txt")
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Đã tạo 40 câu hỏi.
# Câu hỏi được lưu trong: lich_su_hinh_thanh_vnu_questions_en.txt
# Đáp án được lưu trong: lich_su_hinh_thanh_vnu_answers_en.txt

# %%
#tao cau hoi va tra loi thong tin tuyen sinh vnu
from transformers import AutoModelWithLMHead, AutoTokenizer
import random

# Tải mô hình và tokenizer từ Hugging Face
model_name = "mrm8488/t5-base-finetuned-question-generation-ap"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)

# Hàm đọc file .txt
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Hàm tạo câu hỏi
def generate_question(answer, context, max_length=64):
    input_text = f"answer: {answer} context: {context} </s>"
    features = tokenizer([input_text], return_tensors='pt')
    output = model.generate(
        input_ids=features['input_ids'],
        attention_mask=features['attention_mask'],
        max_length=max_length
    )
    question = tokenizer.decode(output[0], skip_special_tokens=True)
    return question.replace("question: ", "").strip()

# Hàm tạo nhiều câu hỏi và đáp án
def generate_multiple_questions(file_path, num_questions=10):
    text = read_text_file(file_path)
    sentences = sent_tokenize(text)  # Tách văn bản thành các câu
    questions = []
    answers = []

    # Lặp để tạo câu hỏi
    for _ in range(num_questions):
        if not sentences:
            break
        # Chọn ngẫu nhiên một câu làm ngữ cảnh
        context = random.choice(sentences)
        # Chọn một cụm từ hoặc danh từ làm đáp án
        words = context.split()
        answer = random.choice([word for word in words if len(word) > 3])  # Lọc từ ngắn
        try:
            question = generate_question(answer, context)
            questions.append(question)
            answers.append(answer)
        except:
            continue

    return questions, answers

# Hàm lưu câu hỏi và đáp án vào file riêng
def save_to_files(questions, answers, questions_file="questions.txt", answers_file="answers.txt"):
    # Lưu câu hỏi
    with open(questions_file, "w", encoding="utf-8") as q_file:
        for question in questions:
            q_file.write(f"{question}\n")

    # Lưu đáp án
    with open(answers_file, "w", encoding="utf-8") as a_file:
        for answer in answers:
            a_file.write(f"{answer}\n")

# Chạy chương trình
file_path = "data/cleaned_data/en_translated_data/thong_tin_tuyen_sinh_vnu_cleaned_en.txt"  # Đường dẫn đến file .txt
questions, answers = generate_multiple_questions(file_path, num_questions=40)

# Lưu vào file
save_to_files(questions, answers, questions_file="data/questions_answers/questions/thong_tin_tuyen_sinh_vnu_questions_en.txt", answers_file="data/questions_answers/answers/thong_tin_tuyen_sinh_vnu_answers_en.txt")

print(f"Đã tạo {len(questions)} câu hỏi.")
print(f"Câu hỏi được lưu trong: thong_tin_tuyen_sinh_vnu_questions_en.txt")
print(f"Đáp án được lưu trong: thong_tin_tuyen_sinh_vnu_answers_en.txt")
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Token indices sequence length is longer than the specified maximum sequence length for this model (1695 > 512). Running this sequence through the model will result in indexing errors
# Đã tạo 40 câu hỏi.
# Câu hỏi được lưu trong: thong_tin_tuyen_sinh_vnu_questions_en.txt
# Đáp án được lưu trong: thong_tin_tuyen_sinh_vnu_answers_en.txt

# %%
#tao cau hoi va tra loi wikipedia vnu
from transformers import AutoModelWithLMHead, AutoTokenizer
import random

# Tải mô hình và tokenizer từ Hugging Face
model_name = "mrm8488/t5-base-finetuned-question-generation-ap"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)

# Hàm đọc file .txt
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Hàm tạo câu hỏi
def generate_question(answer, context, max_length=64):
    input_text = f"answer: {answer} context: {context} </s>"
    features = tokenizer([input_text], return_tensors='pt')
    output = model.generate(
        input_ids=features['input_ids'],
        attention_mask=features['attention_mask'],
        max_length=max_length
    )
    question = tokenizer.decode(output[0], skip_special_tokens=True)
    return question.replace("question: ", "").strip()

# Hàm tạo nhiều câu hỏi và đáp án
def generate_multiple_questions(file_path, num_questions=10):
    text = read_text_file(file_path)
    sentences = sent_tokenize(text)  # Tách văn bản thành các câu
    questions = []
    answers = []

    # Lặp để tạo câu hỏi
    for _ in range(num_questions):
        if not sentences:
            break
        # Chọn ngẫu nhiên một câu làm ngữ cảnh
        context = random.choice(sentences)
        # Chọn một cụm từ hoặc danh từ làm đáp án
        words = context.split()
        answer = random.choice([word for word in words if len(word) > 3])  # Lọc từ ngắn
        try:
            question = generate_question(answer, context)
            questions.append(question)
            answers.append(answer)
        except:
            continue

    return questions, answers

# Hàm lưu câu hỏi và đáp án vào file riêng
def save_to_files(questions, answers, questions_file="questions.txt", answers_file="answers.txt"):
    # Lưu câu hỏi
    with open(questions_file, "w", encoding="utf-8") as q_file:
        for question in questions:
            q_file.write(f"{question}\n")

    # Lưu đáp án
    with open(answers_file, "w", encoding="utf-8") as a_file:
        for answer in answers:
            a_file.write(f"{answer}\n")

# Chạy chương trình
file_path = "data/cleaned_data/en_translated_data/wikipedia_vnu_cleaned_en.txt"  # Đường dẫn đến file .txt
questions, answers = generate_multiple_questions(file_path, num_questions=40)

# Lưu vào file
save_to_files(questions, answers, questions_file="data/questions_answers/questions/wikipedia_vnu_questions_en.txt", answers_file="data/questions_answers/answers/wikipedia_vnu_answers_en.txt")

print(f"Đã tạo {len(questions)} câu hỏi.")
print(f"Câu hỏi được lưu trong: wikipedia_vnu_questions_en.txt")
print(f"Đáp án được lưu trong: wikipedia_vnu_answers_en.txt")
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Token indices sequence length is longer than the specified maximum sequence length for this model (1378 > 512). Running this sequence through the model will result in indexing errors
# Đã tạo 40 câu hỏi.
# Câu hỏi được lưu trong: wikipedia_vnu_questions_en.txt
# Đáp án được lưu trong: wikipedia_vnu_answers_en.txt

# %%
#tao cau hoi va tra loi tuyen sinh du hoc sinh vnu
from transformers import AutoModelWithLMHead, AutoTokenizer
import random

# Tải mô hình và tokenizer từ Hugging Face
model_name = "mrm8488/t5-base-finetuned-question-generation-ap"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)

# Hàm đọc file .txt
def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# Hàm tạo câu hỏi
def generate_question(answer, context, max_length=64):
    input_text = f"answer: {answer} context: {context} </s>"
    features = tokenizer([input_text], return_tensors='pt')
    output = model.generate(
        input_ids=features['input_ids'],
        attention_mask=features['attention_mask'],
        max_length=max_length
    )
    question = tokenizer.decode(output[0], skip_special_tokens=True)
    return question.replace("question: ", "").strip()

# Hàm tạo nhiều câu hỏi và đáp án
def generate_multiple_questions(file_path, num_questions=10):
    text = read_text_file(file_path)
    sentences = sent_tokenize(text)  # Tách văn bản thành các câu
    questions = []
    answers = []

    # Lặp để tạo câu hỏi
    for _ in range(num_questions):
        if not sentences:
            break
        # Chọn ngẫu nhiên một câu làm ngữ cảnh
        context = random.choice(sentences)
        # Chọn một cụm từ hoặc danh từ làm đáp án
        words = context.split()
        answer = random.choice([word for word in words if len(word) > 3])  # Lọc từ ngắn
        try:
            question = generate_question(answer, context)
            questions.append(question)
            answers.append(answer)
        except:
            continue

    return questions, answers

# Hàm lưu câu hỏi và đáp án vào file riêng
def save_to_files(questions, answers, questions_file="questions.txt", answers_file="answers.txt"):
    # Lưu câu hỏi
    with open(questions_file, "w", encoding="utf-8") as q_file:
        for question in questions:
            q_file.write(f"{question}\n")

    # Lưu đáp án
    with open(answers_file, "w", encoding="utf-8") as a_file:
        for answer in answers:
            a_file.write(f"{answer}\n")

# Chạy chương trình
file_path = "data/cleaned_data/en_translated_data/thong_tin_tuyen_sinh_du_hoc_sinh_cleaned_en.txt"  # Đường dẫn đến file .txt
questions, answers = generate_multiple_questions(file_path, num_questions=40)

# Lưu vào file
save_to_files(questions, answers, questions_file="data/questions_answers/questions/thong_tin_tuyen_sinh_du_hoc_sinh_questions_en.txt", answers_file="data/questions_answers/answers/thong_tin_tuyen_sinh_du_hoc_sinh_answers_en.txt")

print(f"Đã tạo {len(questions)} câu hỏi.")
print(f"Câu hỏi được lưu trong: thong_tin_tuyen_sinh_du_hoc_sinh_questions_en.txt")
print(f"Đáp án được lưu trong: thong_tin_tuyen_sinh_du_hoc_sinh_answers_en.txt")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# ...
