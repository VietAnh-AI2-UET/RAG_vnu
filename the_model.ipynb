# %%
# !pip install langchain_huggingface
# !pip install -U langchain-community
# !pip install faiss-cpu
# !pip install underthesea
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-0.2.0-py3-none-any.whl.metadata (941 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (0.3.59)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (4.51.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (4.1.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in /usr/local/lib/python3.11/dist-packages (from langchain_huggingface) (0.31.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->langchain_huggingface) (4.13.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (1.33)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (2.11.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (11.2.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.39.0->langchain_huggingface) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.39.0->langchain_huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.39.0->langchain_huggingface) (0.5.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain_huggingface) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain_huggingface) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain_huggingface) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.30.2->langchain_huggingface) (2025.4.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_huggingface) (1.3.1)
# Downloading langchain_huggingface-0.2.0-py3-none-any.whl (27 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 29.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, langchain_huggingface
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed langchain_huggingface-0.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from langchain_huggingface import HuggingFaceEmbeddings, HuggingFacePipeline
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer
from sentence_transformers import SentenceTransformer
from underthesea import word_tokenize
import faiss
import numpy as np
import torch
import re
import string

# %%
def load_qa_data(questions_file, answers_file):
    with open(questions_file, 'r', encoding='utf-8') as q_file, open(answers_file, 'r', encoding='utf-8') as a_file:
        questions = q = q_file.readlines()
        answers = a_file.readlines()
        qa_pairs = [{"question": q.strip(), "answer": a.strip()} for q, a in zip(questions, answers)]
    return qa_pairs

train_data = load_qa_data('data/train/questions.txt', 'data/train/reference_answers.txt')
test_data = load_qa_data('data/test/questions.txt', 'data/test/reference_answers.txt')
# qa_data = load_qa_data('data/questions_answers/questions/questions.txt', 'data/questions_answers/answers/reference_answers.txt')

# %%
train_data
# Out:
# [{'question': 'Tên của trường đại học đầu tiên ở Việt Nam là gì?',
#   'answer': 'đại học'},
#  {'question': 'Trọng tâm chính của trường mới thành lập tại Đại học Quốc gia Việt Nam là gì?',
#   'answer': 'dược'},
#  {'question': 'Tên của trường đại học mới thành lập năm 2003 là gì?',
#   'answer': 'đã'},
#  {'question': 'Chính phủ đã làm gì với Khoa Giáo dục?', 'answer': 'nâng cấp'},
#  {'question': 'Mục đích của việc thành lập Đại học Quốc gia là gì?',
#   'answer': 'với'},
#  {'question': 'Đại học Quốc gia Việt Nam giống với kiểu nền văn minh nào?',
#   'answer': 'con người'},
#  {'question': 'Tên gọi của đợt sáp nhập và tổ chức lại Trung tâm Ứng dụng công nghệ thông tin là gì?',
#   'answer': 'dựa trên'},
#  {'question': 'Tên của điều lệ do Thủ tướng Chính phủ ban hành năm 2001 là gì?',
#   'answer': 'hoạt động'},
#  {'question': 'Tên gọi mới của Trung tâm Nghiên cứu Phát triển và Đảm bảo chất lượng giáo dục là gì?',
#   'answer': 'giáo dục'},
#  {'question': 'Đại học Quốc gia chính thức đi vào hoạt động khi nào?',
#   'answer': 'bắt đầu'},
#  {'question': 'Tên gọi mới của trung tâm ứng dụng công nghệ thông tin là gì?',
#   'answer': 'các đơn vị'},
#  {'question': 'ĐHQGHN phải cung cấp loại hình đào tạo nào?',
#   'answer': 'chất lượng cao'},
#  {'question': 'Chính phủ đã làm gì với ĐHQGHN vào năm 2006?',
#   'answer': 'thành lập'},
#  {'question': 'Bước đầu tiên của mô hình ĐHQGHN là gì?',
#   'answer': 'phát triển'},
#  {'question': 'Trường Đại học Công nghệ đã nâng cấp Khoa nào?',
#   'answer': 'công nghệ'},
#  {'question': 'Tên của trung tâm ứng dụng công nghệ thông tin là gì?',
#   'answer': 'thông tin'},
#  {'question': 'Tên gọi mới của trung tâm ứng dụng công nghệ thông tin là gì?',
#   'answer': 'các đơn vị'},
#  {'question': 'Văn bản nào được Thủ tướng Chính phủ ban hành năm 2001?',
#   'answer': 'điều lệ'},
#  {'question': 'Đại học Quốc gia Việt Nam kế thừa mô hình đại học nào từ Đại học Đông Dương?',
#   'answer': 'quốc gia'},
#  {'question': 'Tên của trường đại học đầu tiên ở Việt Nam là gì?',
#   'answer': 'đại học'},
#  {'question': 'Tên gọi mới của Trung tâm Nghiên cứu Phát triển và Đảm bảo chất lượng giáo dục là gì?',
#   'answer': 'giáo dục'},
#  {'question': 'Thủ tướng Chính phủ đã làm gì với Điều lệ Tổ chức và Hoạt động của Đại học Quốc gia Việt Nam?',
#   'answer': 'ban hành'},
#  {'question': 'ĐHQGHN có quyền tự chủ cao trong loại hình đào tạo nào?',
#   'answer': 'nghiên cứu'},
#  {'question': 'Trung tâm Nghiên cứu Phát triển và Đảm bảo chất lượng giáo dục được đổi tên thành gì?',
#   'answer': 'viện'},
#  {'question': 'Đại học Quốc gia Việt Nam có nguồn gốc từ đâu?',
#   'answer': 'từ'},
#  {'question': 'Mục đích của quyết định về THU HÚT và QUẢN LÝ sinh viên quốc tế là gì?',
#   'answer': 'điều'},
#  {'question': 'Ngày hết hạn của hộ chiếu sinh viên là gì?',
#   'answer': 'thời gian'},
#  {'question': 'Quy trình xin cấp chứng chỉ năng lực tiếng Việt là gì?',
#   'answer': 'áp dụng'},
#  {'question': 'Điều kiện nào được cung cấp cho sinh viên quốc tế tại ĐHQGHN?',
#   'answer': 'thuận lợi'},
#  {'question': 'ĐHQGHN cung cấp gì cho sinh viên quốc tế?',
#   'answer': 'dịch vụ'},
#  {'question': 'Sinh viên quốc tế phải làm gì để được xét học bổng?',
#   'answer': 'đáp ứng'},
#  {'question': 'Việc kiểm tra sinh viên quốc tế được thực hiện như thế nào?',
#   'answer': 'thực hiện'},
#  {'question': 'Trách nhiệm của đơn vị đào tạo trong việc xác minh văn bằng là gì?',
#   'answer': 'kiểm tra'},
#  {'question': 'Khi nào giấy chứng nhận được cấp cho sinh viên quốc tế?',
#   'answer': 'sau đó'},
#  {'question': 'Ngôn ngữ của sinh viên phải là một phần của chương trình đào tạo là gì?',
#   'answer': 'với'},
#  {'question': 'Loại văn bằng nào được yêu cầu để sinh viên quốc tế được chấp nhận vào ĐHQGHN?',
#   'answer': 'tiến sĩ'},
#  {'question': 'Thông tin về chỗ ở và dịch vụ cho sinh viên quốc tế được công bố ở đâu?',
#   'answer': 'xuất bản'},
#  {'question': 'Thỏa thuận giữa hai bên với Đại học Quốc gia Việt Nam là gì?',
#   'answer': 'giữa'},
#  {'question': 'Điều kiện của sinh viên quốc tế tại Việt Nam là gì?',
#   'answer': 'điều kiện'},
#  {'question': 'Các đơn vị đào tạo của ĐHQGHN thiết kế gì để thu hút sinh viên quốc tế?',
#   'answer': 'các chương trình'},
#  {'question': 'Ai chịu trách nhiệm quyết định việc tiếp nhận sinh viên quốc tế vào ĐHQGHN?',
#   'answer': 'sinh viên'},
#  {'question': 'Thông tư số 032014TTBGDT được ban hành vào thời gian nào?',
#   'answer': 'tháng hai'},
#  {'question': 'Trách nhiệm của ĐHQGHN trong việc đảm bảo sinh viên quốc tế được tiếp nhận vào chương trình là gì?',
#   'answer': 'đào tạo'},
#  {'question': 'Mẫu đơn xin nhập học của sinh viên quốc tế vào ĐHQGHN là gì?',
#   'answer': 'lấp đầy'},
#  {'question': 'Ngôn ngữ chính thức của Việt Nam là gì?', 'answer': 'việt nam'},
#  {'question': 'ĐHQGHN xác định yêu cầu gì đối với sinh viên quốc tế?',
#   'answer': 'chương trình'},
#  {'question': 'Việc xét duyệt hồ sơ nhập học của sinh viên quốc tế diễn ra khi nào?',
#   'answer': 'từ'},
#  {'question': 'ĐHQGHN làm gì để thu hút sinh viên quốc tế?',
#   'answer': 'các hoạt động'},
#  {'question': 'Ngành đào tạo được phê duyệt cho sinh viên quốc tế là gì?',
#   'answer': 'lĩnh vực'},
#  {'question': 'Trách nhiệm của ĐHQGHN trong việc đảm bảo sinh viên quốc tế được tiếp nhận vào chương trình là gì?',
#   'answer': 'đào tạo'},
#  {'question': 'Khi nào sinh viên quốc tế phải được thông báo về quyết định tiếp nhận vào chương trình đào tạo?',
#   'answer': 'trước'},
#  {'question': 'Tương đương với bằng tốt nghiệp trung học phổ thông là gì?',
#   'answer': 'tương đương'},
#  {'question': 'Yêu cầu đối với sinh viên quốc tế để được xét học bổng là gì?',
#   'answer': 'lý lịch'},
#  {'question': 'Quy trình xác định đủ điều kiện của sinh viên quốc tế cho chương trình đào tạo tại ĐHQGHN là gì?',
#   'answer': 'xem xét'},
#  {'question': 'ĐHQGHN xác định yêu cầu gì đối với sinh viên quốc tế?',
#   'answer': 'chương trình'},
#  {'question': 'Trách nhiệm của ĐHQGHN và các trường đại học nước ngoài trong việc xác định sinh viên quốc tế là gì?',
#   'answer': 'tuân thủ'},
#  {'question': 'Yêu cầu đối với sinh viên quốc tế được ĐHQGHN quản lý như thế nào?',
#   'answer': 'theo'},
#  {'question': 'ĐHQGHN chịu trách nhiệm công bố kết quả tuyển sinh cho ai?',
#   'answer': 'sinh viên'},
#  {'question': 'Ngôn ngữ chính thức của Việt Nam là gì?', 'answer': 'việt nam'},
#  {'question': 'Ai chịu trách nhiệm quyết định việc tiếp nhận sinh viên quốc tế vào ĐHQGHN?',
#   'answer': 'sinh viên'},
#  {'question': 'Mục đích chính của chương trình đào tạo cho sinh viên quốc tế là gì?',
#   'answer': 'học tập'},
#  {'question': 'Ai đã ban hành quyết định về việc ban hành chương trình đào tạo?',
#   'answer': 'chủ tịch'},
#  {'question': 'Quyết định về thu hút và quản lý sinh viên quốc tế tại Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'quyết định'},
#  {'question': 'Mục đích của quyết định về THU HÚT và QUẢN LÝ sinh viên quốc tế là gì?',
#   'answer': 'này'},
#  {'question': 'Loại sinh viên nào phải là công dân của quốc gia có ngôn ngữ chính thức là tiếng Việt?',
#   'answer': 'quốc tế'},
#  {'question': 'Mức điểm thưởng cho việc quy đổi điểm chứng chỉ sang thang điểm 10 là gì?',
#   'answer': 'ưu tiên'},
#  {'question': 'Phương pháp giáo dục chính là gì?', 'answer': 'tuyển sinh'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Yếu tố nào được sử dụng trong kỳ thi Đánh giá năng lực học sinh THPT?',
#   'answer': 'chứng chỉ'},
#  {'question': 'Yếu tố nào được sử dụng trong kỳ thi Đánh giá năng lực học sinh THPT?',
#   'answer': 'chứng chỉ'},
#  {'question': 'Yếu tố nào được sử dụng trong kỳ thi Đánh giá năng lực học sinh THPT?',
#   'answer': 'chứng chỉ'},
#  {'question': 'Có bao nhiêu điểm thưởng cho chứng chỉ ngoại ngữ?',
#   'answer': 'bao gồm'},
#  {'question': 'Kỳ thi Đánh giá năng lực học sinh THPT là gì?',
#   'answer': 'cao'},
#  {'question': 'Ngành học trong chương trình của ĐHQGHN là gì?',
#   'answer': 'nghiên cứu'},
#  {'question': 'Thí sinh cần xem gì trong mục 4 Điểm ưu tiên 30?',
#   'answer': 'chi tiết'},
#  {'question': 'Loại chứng chỉ nào được coi là điểm cộng cho thí sinh đạt được?',
#   'answer': 'quốc tế'},
#  {'question': 'Kết quả của kỳ thi Đánh giá năng lực học sinh THPT do ĐHQGHN tổ chức được sử dụng để tuyển sinh như thế nào?',
#   'answer': 'dựa trên'},
#  {'question': 'Phương thức xét tuyển dựa trên kết quả kỳ thi tốt nghiệp THPT 2025 là gì?',
#   'answer': 'tuyển sinh'},
#  {'question': 'Khi nào ĐHQGHN sử dụng chứng chỉ ngoại ngữ để tuyển sinh?',
#   'answer': '2025'},
#  {'question': 'Kỳ thi Đánh giá năng lực học sinh THPT là gì?',
#   'answer': 'trường'},
#  {'question': 'Loại chứng chỉ nào được coi là điểm cộng cho thí sinh đạt được?',
#   'answer': 'quốc tế'},
#  {'question': 'Địa chỉ Phạm Văn Đồng là gì?', 'answer': 'phố'},
#  {'question': 'Tên của cơ sở sử dụng chứng chỉ ngoại ngữ là gì?',
#   'answer': 'đại học'},
#  {'question': 'Số điểm cộng cho chứng chỉ ngoại ngữ là bao nhiêu?',
#   'answer': 'ưu tiên'},
#  {'question': 'Số điện thoại của Phòng Tuyển sinh ĐHQGHN là gì?',
#   'answer': '842437548057'},
#  {'question': 'Bộ Giáo dục và Đào tạo có trách nhiệm gì?',
#   'answer': 'đào tạo'},
#  {'question': 'Bộ Giáo dục và Đào tạo có trách nhiệm gì?',
#   'answer': 'đào tạo'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Có bao nhiêu điểm thưởng cho mỗi phương thức tuyển sinh?',
#   'answer': 'tổng'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Ai đủ điều kiện tham gia kỳ thi Đánh giá năng lực?',
#   'answer': 'sinh viên'},
#  {'question': 'Số điểm được trao cho thí sinh đạt giải trong các kỳ thi là bao nhiêu?',
#   'answer': 'thưởng'},
#  {'question': 'Thông tin chi tiết về phương thức tuyển sinh được tìm thấy ở đâu?',
#   'answer': 'phần'},
#  {'question': 'Tên của tài liệu mô tả quy trình tuyển sinh là gì?',
#   'answer': 'ghi chú'},
#  {'question': 'Phương thức tuyển sinh dựa trên kết quả kỳ thi tốt nghiệp THPT 2025 là gì?',
#   'answer': 'kỳ thi'},
#  {'question': 'Ngôn ngữ nào được sử dụng trong quy trình tuyển sinh 2025 tại ĐHQGHN?',
#   'answer': 'tiếng trung'},
#  {'question': 'Ngôn ngữ nào được sử dụng trong quy trình tuyển sinh 2025 tại ĐHQGHN?',
#   'answer': 'tiếng trung'},
#  {'question': 'Phương pháp giáo dục chính là gì?', 'answer': 'tuyển sinh'},
#  {'question': 'Loại chứng chỉ nào được sử dụng trong tuyển sinh đại học chính quy?',
#   'answer': 'ngôn ngữ'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Có bao nhiêu điểm thưởng cho thí sinh đạt giải trong các kỳ thi?',
#   'answer': 'điểm'},
#  {'question': 'Loại tuyển sinh nào được sử dụng vào năm 2025?',
#   'answer': 'đại học'},
#  {'question': 'Loại tuyển sinh đại học nào ĐHQGHN cung cấp năm 2024?',
#   'answer': 'toàn thời gian'},
#  {'question': 'Loại chứng chỉ nào được yêu cầu để được nhận vào ĐHQGHN?',
#   'answer': 'quốc tế'},
#  {'question': 'Loại tuyển sinh nào ĐHQGHN cung cấp năm 2024?',
#   'answer': 'đại học'},
#  {'question': 'Bước đầu tiên trong quy trình tuyển sinh kỳ thi đánh giá năng lực học sinh THPT 2024 của ĐHQGHN là gì?',
#   'answer': 'tham gia'},
#  {'question': 'Loại chương trình nào ĐHQGHN sử dụng để đào tạo sinh viên?',
#   'answer': 'đào tạo'},
#  {'question': 'Mã đăng ký của kỳ thi SAT là gì?', 'answer': 'với'},
#  {'question': 'Kỳ thi tốt nghiệp THPT 2024 là gì?', 'answer': 'kỳ thi'},
#  {'question': 'Loại chương trình đào tạo nào là chương trình đào tạo Kinh doanh của ĐHQGHN?',
#   'answer': 'kỹ thuật số'},
#  {'question': 'Ngành học chính tại ĐHQGHN là gì?', 'answer': 'kinh doanh'},
#  {'question': 'Danh sách tuyển sinh đại học chính quy năm 2023 của ĐHQGHN là gì?',
#   'answer': 'các chương trình'},
#  {'question': 'Loại tuyển sinh đại học nào ĐHQGHN cung cấp năm 2024?',
#   'answer': 'toàn thời gian'},
#  {'question': 'Loại tuyển sinh đại học nào ĐHQGHN cung cấp năm 2024?',
#   'answer': 'toàn thời gian'},
#  {'question': 'Tên của kỳ thi được tổ chức bởi ĐHQGHN để xác định trình độ năng lực của học sinh là gì?',
#   'answer': 'đánh giá'},
#  {'question': 'Kỳ thi đánh giá năng lực năm 2024 cung cấp gì?',
#   'answer': 'thông tin'},
#  {'question': 'Tên của diễn đàn sinh viên do Đại học Quốc gia Hà Nội tổ chức là gì?',
#   'answer': 'diễn đàn'},
#  {'question': 'Ngành học chính tại Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'khoa học'},
#  {'question': 'ĐHQGHN có những điều kiện gì để sinh viên có thể theo học tại đây?',
#   'answer': 'quy định'},
#  {'question': 'Môn học duy nhất phải có trong kỳ thi tốt nghiệp THPT năm 2024 là gì?',
#   'answer': 'văn học'},
#  {'question': 'Môn học đầu tiên của VNUUET là gì?', 'answer': 'đồ họa'},
#  {'question': 'Loại chương trình nào ĐHQGHN sử dụng để đào tạo sinh viên?',
#   'answer': 'đào tạo'},
#  {'question': 'Tên của diễn đàn sinh viên do Đại học Quốc gia Hà Nội tổ chức là gì?',
#   'answer': 'diễn đàn'},
#  {'question': 'Loại tuyển sinh nào ĐHQGHN cung cấp năm 2024?',
#   'answer': 'đại học'},
#  {'question': 'Tên của kỳ thi đánh giá năng lực học sinh THPT năm 2024 của ĐHQGHN là gì?',
#   'answer': 'trường'},
#  {'question': 'Điều gì được xác định vào thời điểm xét tuyển trước khi công bố kết quả trúng tuyển chính thức?',
#   'answer': 'các môn học'},
#  {'question': 'Điểm cuối cùng của kỳ thi ACT American College Testing là gì?',
#   'answer': 'kết quả'},
#  {'question': 'ĐHQGHN dự kiến tuyển sinh các chương trình đào tạo vào năm 2024 như thế nào?',
#   'answer': 'hạn ngạch'},
#  {'question': 'Có bao nhiêu thí sinh tham dự đợt 2 kỳ thi Đánh giá năng lực 2024 của ĐHQGHN?',
#   'answer': '18000'},
#  {'question': 'Điểm tối thiểu cho kỳ thi tốt nghiệp THPT năm 2024 là bao nhiêu?',
#   'answer': 'cao'},
#  {'question': 'ĐHQGHN dự kiến tuyển sinh các chương trình đào tạo vào năm 2024 như thế nào?',
#   'answer': 'hạn ngạch'},
#  {'question': 'Mục đích của kỳ thi Đánh giá năng lực 2024 của ĐHQGHN là gì?',
#   'answer': 'công việc'},
#  {'question': 'Có bao nhiêu thí sinh tham dự đợt 2 kỳ thi Đánh giá năng lực 2024 của ĐHQGHN?',
#   'answer': 'hơn'},
#  {'question': 'Điểm cuối cùng của kỳ thi ACT American College Testing là gì?',
#   'answer': 'kết quả'},
#  {'question': 'Loại chương trình nào ĐHQGHN sử dụng để đào tạo sinh viên?',
#   'answer': 'đào tạo'},
#  {'question': 'ĐHQGHN duy trì điều gì liên quan đến kỳ thi đánh giá năng lực học sinh THPT năm 2024?',
#   'answer': 'phương pháp'},
#  {'question': 'Bằng trung cấp nghề là gì?', 'answer': 'lĩnh vực'},
#  {'question': 'ĐHQGHN tuyển sinh trên phạm vi toàn quốc cho đối tượng nào?',
#   'answer': 'sinh viên'},
#  {'question': 'Điều gì được xác định vào thời điểm xét tuyển trước khi công bố kết quả trúng tuyển chính thức?',
#   'answer': 'các môn học'},
#  {'question': 'Điều gì được xác định vào thời điểm xét tuyển trước khi công bố kết quả trúng tuyển chính thức?',
#   'answer': 'tuyển sinh'},
#  {'question': 'Trường Đại học Giáo dục có bao nhiêu chỉ tiêu?',
#   'answer': '1150'},
#  {'question': 'Ngưỡng đảm bảo chất lượng đầu vào của sinh viên tại ĐHQGHN là gì?',
#   'answer': 'ngưỡng'},
#  {'question': 'Đại học Quốc gia Hà Nội có gì trong tên gọi của mình?',
#   'answer': 'các đại học'},
#  {'question': 'Tên của Đại học Quốc gia Hà Nội là gì?', 'answer': 'đại học'},
#  {'question': 'Đại học Quốc gia Hà Nội có bao nhiêu giảng viên?',
#   'answer': '4393'}]

# %%
test_data
# Out:
# [{'question': 'Thủ tướng Chính phủ đã ban hành điều gì vào năm 2002?',
#   'answer': 'quyết định'},
#  {'question': 'Tên của trường đại học được tách ra từ Trường Đại học Khoa học Tự nhiên là gì?',
#   'answer': 'giáo dục'},
#  {'question': 'Thủ tướng Chính phủ đã làm gì vào năm 2004?',
#   'answer': 'tham dự'},
#  {'question': 'Cơ sở cho việc thành lập Trường Đại học Công nghệ là gì?',
#   'answer': 'cơ sở'},
#  {'question': 'Các đơn vị khác nằm trong Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'khác'},
#  {'question': 'Một số đơn vị trực thuộc Đại học Quốc gia Hà Nội sẽ được chuyển đến đâu vào năm 2015?',
#   'answer': 'khuôn viên'},
#  {'question': 'Các đơn vị khác nằm trong Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'khác'},
#  {'question': 'Tên của hệ thống đại học ở Việt Nam là gì?',
#   'answer': 'quốc gia'},
#  {'question': 'Tên của Đại học Quốc gia Hà Nội là gì?', 'answer': 'đại học'},
#  {'question': 'Quốc gia nào có khu đô thị đại học lớn nhất Việt Nam?',
#   'answer': 'việt nam'},
#  {'question': 'Loại cơ sở đào tạo nào Đại học Quốc gia Hà Nội có?',
#   'answer': 'các trung tâm'},
#  {'question': 'Tên cũ của Trường Đại học Khoa học Tự nhiên là gì?',
#   'answer': 'sư phạm'},
#  {'question': 'Trọng tâm chính của Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'ngôn ngữ'},
#  {'question': 'Tiền thân của Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'đông dương'},
#  {'question': 'Đại học Quốc gia Hà Nội là loại viện nào?',
#   'answer': 'nghiên cứu'},
#  {'question': 'Mục tiêu của việc chuyển trụ sở Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'di dời'},
#  {'question': 'Trụ sở cũ của Đại học Quốc gia Hà Nội nằm ở đâu?',
#   'answer': 'xuân'},
#  {'question': 'Trường Khoa học Cơ bản được thành lập khi nào?',
#   'answer': 'sau đó'},
#  {'question': 'Loại hình giáo dục nào được Đại học Quốc gia Hà Nội cung cấp?',
#   'answer': 'tổng quát'},
#  {'question': 'Đại học Quốc gia Hà Nội cung cấp đào tạo các ngành khoa học và nhân văn nào?',
#   'answer': 'xã hội'},
#  {'question': 'Các viện nghiên cứu nào Đại học Quốc gia Hà Nội có?',
#   'answer': 'các viện'},
#  {'question': 'Ngành học đầu tiên tại Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'kinh tế'},
#  {'question': 'Trụ sở cũ của Đại học Đông Dương nằm ở đâu?',
#   'answer': 'thanh'},
#  {'question': 'Mục tiêu của việc di dời các đơn vị trực thuộc đến cơ sở Hòa Lạc là gì?',
#   'answer': 'một số'},
#  {'question': 'Loại hình giáo dục nào Đại học Quốc gia Hà Nội cung cấp?',
#   'answer': 'ứng dụng'},
#  {'question': 'Cơ sở cho việc thành lập Trường Đại học Công nghệ là gì?',
#   'answer': 'cơ sở'},
#  {'question': 'Các viện nghiên cứu nào Đại học Quốc gia Hà Nội cung cấp?',
#   'answer': 'khoa học'},
#  {'question': 'Thủ tướng Chính phủ Việt Nam đã ban hành lệnh khởi công xây dựng Đại học Quốc gia Hà Nội vào thời gian nào?',
#   'answer': 'tháng mười hai'},
#  {'question': 'Trường Đại học Giáo dục được thành lập vào năm nào?',
#   'answer': '2009'},
#  {'question': 'Loại đơn vị nào sẽ được di dời đến cơ sở Hòa Lạc vào năm 2015?',
#   'answer': 'liên kết'},
#  {'question': 'Trường Khoa học Cơ bản của Đại học Quốc gia Hà Nội có nguồn gốc từ đâu?',
#   'answer': 'từ'},
#  {'question': 'Loại đơn vị nào thuộc sự quản lý của Đại học Quốc gia Hà Nội?',
#   'answer': 'các đơn vị'},
#  {'question': 'Diện tích đất của Đại học Quốc gia Hà Nội là bao nhiêu?',
#   'answer': 'nông trại'},
#  {'question': 'Quốc gia nào có khu đô thị đại học lớn nhất Việt Nam?',
#   'answer': 'việt nam'},
#  {'question': 'Trường Đại học Giáo dục tách ra khỏi Trường Đại học Khoa học Tự nhiên vào thời gian nào?',
#   'answer': '1999'},
#  {'question': 'Tên của khu ký túc xá tại Đại học Quốc gia Hà Nội là gì?',
#   'answer': 'cụ thể là'},
#  {'question': 'Đại học Quốc gia Hà Nội đào tạo các ngành khoa học nào?',
#   'answer': 'tự nhiên'}]

# %%
# Tạo embedding
embedder = SentenceTransformer('intfloat/multilingual-e5-large')
train_questions = [qa['question'] for qa in train_data]
question_embeddings = embedder.encode(train_questions, convert_to_numpy=True)

# Tạo index FAISS
dimension = question_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(question_embeddings)

# %%
# Tạo vector store
embeddings = HuggingFaceEmbeddings(model_name='intfloat/multilingual-e5-large')
vector_store = FAISS.from_texts(train_questions, embeddings, metadatas=train_data)

# Load mô hình và tokenizer cho Qwen2-0.5B-Instruct
model_id = "Qwen/Qwen2-0.5B-Instruct"
try:
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        device_map="auto",  # Chạy trên CPU
        torch_dtype=torch.float16
    )
except Exception as e:
    print(f"Lỗi khi tải mô hình: {e}")
    exit()

# Tạo pipeline text-generation
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256,
)

# Tạo HuggingFacePipeline cho LangChain
llm = HuggingFacePipeline(pipeline=pipe)

# Tùy chỉnh prompt
prompt_template = """Dựa trên thông tin sau, trả lời câu hỏi một cách chính xác, ngắn gọn và bằng tiếng Việt:

Thông tin: {context}

Câu hỏi: {question}

Câu trả lời: """
prompt = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

# Tạo RetrievalQA chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vector_store.as_retriever(search_kwargs={"k": 5}),
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)
# Out:
# Device set to use cuda:0

# %%
# Hàm trích xuất câu trả lời cuối cùng
def extract_answer(output):
    # Tách output thành các dòng
    lines = output.strip().split('\n')
    # Tìm dòng cuối cùng bắt đầu bằng "Câu trả lời: "
    for line in reversed(lines):
        if line.startswith("Câu trả lời: "):
            return line[len("Câu trả lời: "):].strip()
    return output.strip()  # Nếu không tìm thấy, trả về output đã làm sạch

# %%
# evaluation
# Hàm chuẩn hóa và đánh giá
def normalize_text(text):
    text = text.lower()
    text = re.sub(f'[{string.punctuation}]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def tokenize(text):
    return word_tokenize(text, format="text").split()

def compute_metrics(system_answer, reference_answer):
    system_tokens = tokenize(normalize_text(system_answer))
    reference_tokens = tokenize(normalize_text(reference_answer))
    em = 1 if normalize_text(system_answer) == normalize_text(reference_answer) else 0
    common_tokens = set(system_tokens) & set(reference_tokens)
    recall = len(common_tokens) / len(reference_tokens) if reference_tokens else 0
    precision = len(common_tokens) / len(system_tokens) if system_tokens else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    return {"exact_match": em, "recall": recall, "precision": precision, "f1": f1}

# %%
# Đánh giá trên dataset test
total_metrics = {"exact_match": 0, "recall": 0, "precision": 0, "f1": 0}
num_questions = len(test_data)

for item in test_data:
    try:
        result = qa_chain.invoke({"query": item['question']})
        system_answer = extract_answer(result['result'])
        reference_answer = item['answer']
        metrics = compute_metrics(system_answer, reference_answer)
        for key in total_metrics:
            total_metrics[key] += metrics[key]
    except Exception as e:
        print(f"Lỗi khi xử lý câu hỏi '{item['question']}': {e}")

# Tính trung bình
for key in total_metrics:
    total_metrics[key] /= num_questions if num_questions > 0 else 1

# In hiệu suất
print("\nHiệu suất trung bình trên dataset test:")
print(f"Exact Match: {total_metrics['exact_match']:.4f}")
print(f"Recall: {total_metrics['recall']:.4f}")
print(f"Precision: {total_metrics['precision']:.4f}")
print(f"F1: {total_metrics['f1']:.4f}")
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Hiệu suất trung bình trên dataset test:
# Exact Match: 0.0000
# Recall: 0.1486
# Precision: 0.0191
# F1: 0.0318

# %%
# Vòng lặp để nhập câu hỏi
while True:
    query = input("Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát): ")
    if not query.strip():
        print("Đã thoát.")
        break
    try:
        result = qa_chain.invoke({"query": query})
        answer = extract_answer(result['result'])  # Trích xuất câu trả lời
        print(answer)
    except Exception as e:
        print(f"Lỗi khi xử lý câu hỏi: {e}")
# Out:
# Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát): Tên của trường đại học đầu tiên ở Việt Nam là gì?
# Trường Đại học Quốc gia Việt Nam.
# Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát): Tên của trường đại học mới thành lập năm 2003 là gì?
# Trường Đại học Khoa học Tự nhiên.
# Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát): trường đại học nào thành lập vào năm 2003
# Trường Đại học Giáo dục.
# Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát): trường đại học quốc tử giám là trường nào
# Trường Đại học Quốc Gia Hà Nội là trường đại học.
# Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát): Trường Đại học Quốc gia Việt Nam thành lập vào năm nào
# 1958.
# Nhập câu hỏi của bạn (hoặc nhấn Enter để thoát):
# Đã thoát.
